# %% [markdown]
# <a href="https://colab.research.google.com/github/fmassini/DataScienceCoderhouse/blob/main/Anteriores/Datasets_Massini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Files
import pandas as pd
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Files

# %% [markdown]
# DATASET 1
#
# El conjunto de datos proviene de FIFA 23 de EA Sports. Contiene información sobre jugadores de fútbol, como nombre, edad, nacionalidad, posición, calificaciones y contratos durante la temporada de fútbol 2022/2023. Los datos se recopilaron mediante seguimiento en vivo, investigación y pruebas realizadas por FIFA, funcionarios de la liga y analistas que cubrieron cada partido.
#
# En el fútbol profesional, los jugadores a menudo se evalúan en función de una variedad de atributos, como su velocidad, habilidad y calificación general. Sin embargo, no está claro si existen diferencias en las calificaciones de los jugadores según su nacionalidad, edad, u otro atributo. Esta investigación tiene como objetivo explorar la relación entre las variables de un jugador de fútbol y sus calificaciones utilizando datos del conjunto de datos de jugadores de FIFA 23. Se podría haber predicho el campeón del mundo con esta información?
#
# https://www.kaggle.com/datasets/babatundezenith/fifa-archive?resource=download

# %% [markdown]
# Algunas variables de interés:

# %%
FIFA=pd.read_excel('Fifa_23_Players_Data.xlsx',sheet_name='Hoja2')
FIFA
# Out:
#                COLUMNA                    DESCRIPCIÓN            EJEMPLO 1  \
# 0            Full Name             NOMBRE DEL JUGADOR         Lionel Messi
# 1              Overall              VALORACIÓN ACTUAL                   91
# 2            Potential  VALORACIÓN POTENCIAL A FUTURO                   91
# 3       Value(in Euro)              VALOR DEL JUGADOR             54000000
# 4     Positions Played                       POSICIÓN                   RW
# 5          Nationality                   NACIONALIDAD            Argentina
# 6                  Age                           EDAD                   35
# 7        Height(in cm)                         ALTURA                  169
# 8        Weight(in kg)                           PESO                   67
# 9           TotalStats             TOTAL ESTADÍSTICAS                 2190
# 10           BaseStats              ESTADÍSTICAS BASE                  452
# ...

# %% [markdown]
# DATASET:

# %%
FIFA=pd.read_excel('Fifa_23_Players_Data.xlsx',sheet_name='Hoja1')
FIFA
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4          K. MbappÃ©      Kylian MbappÃ©       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 17524      D. Collins      Darren Collins       47         56          110000
# 17525    Yang Dejiang        Dejiang Yang       47         57           90000
# 17526       L. Mullan         Liam Mullan       47         67          130000
# 17527    D. McCallion   DaithÃ­ McCallion       47         61          100000
# 17528        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %% [markdown]
# DATASET 2
#
# ¿Es posible predecir si las personas recibieron las vacunas contra la gripe H1N1 y la gripe estacional utilizando la información que compartieron sobre sus antecedentes, opiniones y comportamientos de salud?
#
# Una vacuna para el virus de la gripe H1N1 estuvo disponible para el público a partir de octubre de 2009. A finales de 2009 y principios de 2010, Estados Unidos llevó a cabo la Encuesta Nacional de Gripe H1N1 de 2009. Esta encuesta telefónica preguntó a los encuestados si habían recibido las vacunas contra la gripe H1N1 y la gripe estacional, junto con preguntas sobre ellos mismos. Estas preguntas adicionales abarcaban su situación social, económica y demográfica, opiniones sobre los riesgos de enfermedad y la efectividad de las vacunas, y comportamientos para mitigar la transmisión. Un mejor entendimiento de cómo estas características se relacionan con los patrones personales de vacunación puede proporcionar orientación para futuros esfuerzos de salud pública.
#
# https://www.drivendata.org/competitions/66/flu-shot-learning/page/211/

# %% [markdown]
# Algunas variables de interés:

# %%
H1N1=pd.read_excel('Predict H1N1 and Seasonal Flu Vaccines.xlsx',sheet_name='Hoja2')
H1N1
# Out:
#                         COLUMNA  \
# 0                  h1n1_concern
# 1                h1n1_knowledge
# 2     behavioral_antiviral_meds
# 3          behavioral_avoidance
# 4          behavioral_face_mask
# 5         behavioral_wash_hands
# 6   behavioral_large_gatherings
# 7       behavioral_outside_home
# 8         behavioral_touch_face
# 9              doctor_recc_h1n1
# 10         doctor_recc_seasonal
# 11        chronic_med_condition
# 12                health_worker
# 13             health_insurance
# 14  opinion_h1n1_vacc_effective
# 15            opinion_h1n1_risk
# 16  opinion_h1n1_sick_from_vacc
# 17  opinion_seas_vacc_effective
# 18            opinion_seas_risk
# 19  opinion_seas_sick_from_vacc
# 20                    age_group
# 21                    education
# 22                         race
# 23                          sex
# 24               income_poverty
# 25               marital_status
# 26                  rent_or_own
# 27            employment_status
# ...

# %% [markdown]
# DATASET:

# %%
H1N1=pd.read_excel('Predict H1N1 and Seasonal Flu Vaccines.xlsx',sheet_name='Hoja1')
H1N1
# Out:
#        respondent_id  h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# 0                  0           1.0             0.0                        0.0
# 1                  1           3.0             2.0                        0.0
# 2                  2           1.0             1.0                        0.0
# 3                  3           1.0             1.0                        0.0
# 4                  4           2.0             1.0                        0.0
# ...              ...           ...             ...                        ...
# 53410          53410           1.0             1.0                        0.0
# 53411          53411           3.0             1.0                        0.0
# 53412          53412           0.0             1.0                        0.0
# 53413          53413           3.0             1.0                        0.0
# 53414          53414           2.0             1.0                        0.0
#
# ...

# %% [markdown]
# DATASET 3
#
# El siguiente dataset contiene información sobre las piezas con su respectivo código (referencia) necesarias para construir distintas versiones de un producto en específico.
# La mercadería viene en cajones llamados "bases" dentro de contenedores. A su vez, cada caja en estas bases tiene dentro un número determinado de piezas. En resumen, la pieza viene en cajas, las cuales vienen en bases, las cuales a su vez vienen en contenedores.
#
# Lo interesante a ver en este estudio, es definir si existe un patrón en los contenedores y bases en los cuales viene la mercadería, y si ese patrón además se extiende a las 5 versiones existentes (cada fila además aclara a que versión del producto pertenece la pieza, hay piezas comunes a todos y otras que no lo son).
# Es de particular interés encontrar si existe una combinación de contenedores que, si se los trae primero, esto permita contar con todas las piezas para armar el producto lo antes posible.
#
# Una vez traidos los contenedores, las piezas deberán separarse en clases. Sabiendo el volumen y peso de las mismas, también es de interés determinar que clase es más voluminosa y a cuantas posiciones en una estantería equivaldría. Esto difiere mucho versión a versión?
#
# Fuente: https://docs.google.com/spreadsheets/d/1ouprDoTPf1Ua6wY1ZZ1FbcAgWx1ejaNl/edit?usp=drivesdk&ouid=111044325679429769254&rtpof=true&sd=true

# %% [markdown]
# Algunas variables de interés:

# %%
DSNX=pd.read_excel('DS producto.xlsx',sheet_name='Hoja2')
DSNX
# Out:
#         COLUMNA                                        DESCRIPCIÓN  \
# 0         CLASE           Sector en el cual se ensambla esta pieza
# 1       VERSION  Versión del producto al cual pertenece esta pieza
# 2    CONTENEDOR             Contenedor en el cual viene esta pieza
# 3          BASE                   Base en la cual viene esta pieza
# 4     TIPO BASE                                       Tipo de base
# 5    LARGO BASE                             Largo de la base en mm
# 6    ANCHO BASE                             Ancho de la base en mm
# 7   ALTURA BASE                            Altura de la base en mm
# 8     PESO BASE                              Peso de la base en kg
# 9          CAJA                   Caja en la cual viene esta pieza
# 10    TIPO CAJA                                       Tipo de caja
# 11   LARGO CAJA                             Largo de la caja en mm
# 12   ANCHO CAJA                             Ancho de la caja en mm
# ...

# %% [markdown]
# DATASET:

# %%
DSNX=pd.read_excel('DS producto.xlsx',sheet_name='Hoja1')
DSNX
# Out:
#       CLASE VERSION   CONTENEDOR    BASE   TIPO BASE  LARGO BASE  ANCHO BASE  \
# 0        F1     M42  CMAU4908460  AF0001  IRON FRAME        2110         600
# 1        F1     M42  CMAU4908460  AF0002  IRON FRAME        2110         600
# 2        F1     M42  CMAU4908460  AF0003  IRON FRAME        2110         600
# 3        F1     M42  CMAU4908460  AF0004  IRON FRAME        2110         600
# 4        F1     M42  CMAU4908460  AF0005  IRON FRAME        2110         600
# ...     ...     ...          ...     ...         ...         ...         ...
# 23599     A     A42  MRSU3285393   MP001  IRON FRAME        2250        1700
# 23600     A     A42  MRSU3285393   MP001  IRON FRAME        2250        1700
# 23601     A     A42  MRSU3285393   MP001  IRON FRAME        2250        1700
# 23602     A     A42  MRSU3285393   MP001  IRON FRAME        2250        1700
# 23603     A     A42  MRSU3285393   MP001  IRON FRAME        2250        1700
#
# ...
